# %% [markdown]
# <a href="https://colab.research.google.com/github/manjotmb20/Rdatasets/blob/master/IP_Bi_GRU_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn
import time
import torchtext
import numpy as np

import random

from collections import defaultdict, Counter

import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina' 
plt.style.use('seaborn')

# %%
def read_data(corpus_file, datafields):
  with open(corpus_file, encoding='utf-8') as f:
    examples = []
    words = []
    labels = []
    for line in f:
      print(line)
      line = line.strip()
      if not line:
        examples.append(torchtext.data.Example.fromlist([words, labels], datafields))
        words = []
        labels = []
      else:
        columns = line.split()
        words.append(columns[0])
        labels.append(columns[-1])
  return torchtext.data.Dataset(examples, datafields)

# %%
# !pip install pytorch-crf
from torchcrf import CRF

class RNNCRFTagger(nn.Module):
    
    def __init__(self, text_field, label_field, emb_dim, rnn_size, update_pretrained=False):
        super().__init__()
        
        voc_size = len(text_field.vocab)
        self.n_labels = len(label_field.vocab)       
        
        self.embedding = nn.Embedding(voc_size, emb_dim)
        if text_field.vocab.vectors is not None:
            self.embedding.weight = torch.nn.Parameter(text_field.vocab.vectors, 
                                                       requires_grad=update_pretrained)

        self.rnn = nn.GRU(input_size=emb_dim, hidden_size=rnn_size, 
                          bidirectional=True, num_layers=1)

        self.top_layer = nn.Linear(2*rnn_size, self.n_labels)
 
        self.pad_word_id = text_field.vocab.stoi[text_field.pad_token]
        self.pad_label_id = label_field.vocab.stoi[label_field.pad_token]
    
        self.crf = CRF(self.n_labels)
        
    def compute_outputs(self, sentences):
        embedded = self.embedding(sentences)
        rnn_out, _ = self.rnn(embedded)
        out = self.top_layer(rnn_out)
        
        pad_mask = (sentences == self.pad_word_id).float()
        out[:, :, self.pad_label_id] += pad_mask*10000
        
        return out
                
    def forward(self, sentences, labels):
        # Compute the outputs of the lower layers, which will be used as emission
        # scores for the CRF.
        scores = self.compute_outputs(sentences)

        # We return the loss value. The CRF returns the log likelihood, but we return 
        # the *negative* log likelihood as the loss value.            
        # PyTorch's optimizers *minimize* the loss, while we want to *maximize* the
        # log likelihood.
        return -self.crf(scores, labels)
            
    def predict(self, sentences):
        # Compute the emission scores, as above.
        scores = self.compute_outputs(sentences)

        # Apply the Viterbi algorithm to get the predictions. This implementation returns
        # the result as a list of lists (not a tensor), corresponding to a matrix
        # of shape (n_sentences, max_len).
        return self.crf.decode(scores)
# Out:
# Collecting pytorch-crf
#   Downloading https://files.pythonhosted.org/packages/96/7d/4c4688e26ea015fc118a0327e5726e6596836abce9182d3738be8ec2e32a/pytorch_crf-0.7.2-py3-none-any.whl
# Installing collected packages: pytorch-crf
# Successfully installed pytorch-crf-0.7.2

# %%
# class RNNTagger(nn.Module):
  
#   def __init__(self, text_field, label_field, emb_dim, rnn_size, update_pretrained=False):
#     super().__init__()
    
#     voc_size = len(text_field.vocab)
#     self.n_labels = len(label_field.vocab)       
    
#     # Embedding layer. If we're using pre-trained embeddings, copy them
#     # into our embedding module.
#     self.embedding = nn.Embedding(voc_size, emb_dim)
#     if text_field.vocab.vectors is not None:
#         self.embedding.weight = torch.nn.Parameter(text_field.vocab.vectors,requires_grad=update_pretrained)

#     # RNN layer. We're using a bidirectional GRU with one layer.
#     self.rnn = nn.GRU(input_size=emb_dim, hidden_size=rnn_size, bidirectional=True, num_layers=1)

#     # Output layer. As in the example last week, the input will be two times
#     # the RNN size since we are using a bidirectional RNN.
#     self.top_layer = nn.Linear(2*rnn_size, self.n_labels)

#     # To deal with the padding positions later, we need to know the
#     # encoding of the padding dummy word and the corresponding dummy output tag.
#     self.pad_word_id = text_field.vocab.stoi[text_field.pad_token]
#     self.pad_label_id = label_field.vocab.stoi[label_field.pad_token]

#     # Loss function that we will use during training.
#     self.loss = torch.nn.CrossEntropyLoss(reduction='sum')
      
#   def compute_outputs(self, sentences):
#     # The words in the documents are encoded as integers. The shape of the documents
#     # tensor is (max_len, n_docs), where n_docs is the number of documents in this batch,
#     # and max_len is the maximal length of a document in the batch.

#     # First look up the embeddings for all the words in the documents.
#     # The shape is now (max_len, n_sentences, emb_dim).        
#     embedded = self.embedding(sentences)

#     # Apply the RNN.
#     # The shape of the RNN output tensor is (max_len, n_sentences, 2*rnn_size).
#     rnn_out, _ = self.rnn(embedded)
    
#     # Apply the linear output layer.
#     # The shape of the output tensor is (max_len, n_sentences, n_labels).
#     out = self.top_layer(rnn_out)
    
#     # Find the positions where the token is a dummy padding token.
#     pad_mask = (sentences == self.pad_word_id).float()

#     # For these positions, we add some large number in the column corresponding
#     # to the dummy padding label.
#     out[:, :, self.pad_label_id] += pad_mask*10000

#     return out
              
#   def forward(self, sentences, labels):
#     # As discussed above, this method first computes the predictions, and then
#     # the loss function.
    
#     # Compute the outputs. The shape is (max_len, n_sentences, n_labels).
#     scores = self.compute_outputs(sentences)
    
#     # Flatten the outputs and the gold-standard labels, to compute the loss.
#     # The input to this loss needs to be one 2-dimensional and one 1-dimensional tensor.
#     scores = scores.view(-1, self.n_labels)
#     labels = labels.view(-1)
#     return self.loss(scores, labels)

#   def predict(self, sentences):
#     # Compute the outputs from the linear units.
#     scores = self.compute_outputs(sentences)

#     # Select the top-scoring labels. The shape is now (max_len, n_sentences).
#     predicted = scores.argmax(dim=2)

#     # We transpose the prediction to (n_sentences, max_len), and convert it
#     # to a NumPy matrix.
#     return predicted.t().cpu().numpy()

# %%
# Convert a list of BIO labels, coded as integers, into spans identified by a beginning, an end, and a label.
# To allow easy comparison later, we store them in a dictionary indexed by the start position.
def to_spans(l_ids, voc):
  spans = {}
  current_lbl = None
  current_start = None
  for i, l_id in enumerate(l_ids):
    l = voc[l_id]
    if l[0] == 'B': 
      # Beginning of a named entity: B-something.
      if current_lbl:
        # If we're working on an entity, close it.
        spans[current_start] = (current_lbl, i)
        # Create a new entity that starts here.
        current_lbl = l[2:]
        current_start = i
      elif l[0] == 'I':
        # Continuation of an entity: I-something.
        if current_lbl:
          # If we have an open entity, but its label does not
          # correspond to the predicted I-tag, then we cl
          # the open entity and create a new one
          if current_lbl != l[2:]:
            spans[current_start] = (current_lbl, i)
            current_lbl = l[2:]
            current_start = i
          else:
            # If we don't have an open entity but predict an I tag,
            # we create a new entity starting here even though we're
            # not following the format strictly.
            current_lbl = l[2:]
            current_start = i
        else:
          # Outside: O.
          if current_lbl:
            # If we have an open entity, we close it.
            spans[current_start] = (current_lbl, i)
            current_lbl = None
            current_start = None
  return spans

# Compares two sets of spans and records the results for future aggregation.
def compare(gold, pred, stats):
  for start, (lbl, end) in gold.items():
    stats['total']['gold'] += 1
    stats[lbl]['gold'] += 1
  for start, (lbl, end) in pred.items():
    stats['total']['pred'] += 1
    stats[lbl]['pred'] += 1
  for start, (glbl, gend) in gold.items():
    if start in pred:
      plbl, pend = pred[start]
      if glbl == plbl and gend == pend:
        stats['total']['corr'] += 1
        stats[glbl]['corr'] += 1

# This function combines the auxiliary functions we defined above.
def evaluate_iob(predicted, gold, label_field, stats):
  # The gold-standard labels are assumed to be an integer tensor of shape
  # (max_len, n_sentences), as returned by torchtext.
  gold_cpu = gold.t().cpu().numpy()
  gold_cpu = list(gold_cpu.reshape(-1))

  # The predicted labels assume the format produced by pytorch-crf, so we
  # assume that they have been converted into a list already.
  # We just flatten the list.
  pred_cpu = [l for sen in predicted for l in sen]
  
  # Compute spans for the gold standard and prediction.
  gold_spans = to_spans(gold_cpu, label_field.vocab.itos)
  pred_spans = to_spans(pred_cpu, label_field.vocab.itos)

  # Finally, update the counts for correct, predicted and gold-standard spans.
  compare(gold_spans, pred_spans, stats)

# Computes precision, recall and F-score, given a dictionary that contains
# the counts of correct, predicted and gold-standard items.
def prf(stats):
  if stats['pred'] == 0:
    return 0, 0, 0
  p = stats['corr']/stats['pred']
  r = stats['corr']/stats['gold']
  if p > 0 and r > 0:
    f = 2*p*r/(p+r)
  else:
    f = 0
  return p, r, f

# %%
class Tagger:
    
  def __init__(self, lower):
    self.TEXT = torchtext.data.Field(init_token='<bos>', eos_token='<eos>', sequential=True, lower=lower)
    self.LABEL = torchtext.data.Field(init_token='<bos>', eos_token='<eos>', sequential=True, unk_token=None)
    self.fields = [('text', self.TEXT), ('label', self.LABEL)]
    self.device = 'cuda'
        
  def tag(self, sentences):
    # This method applies the trained model to a list of sentences.
    
    # First, create a torchtext Dataset containing the sentences to tag.
    examples = []
    for sen in sentences:
      labels = ['?']*len(sen) # placeholder
      examples.append(torchtext.data.Example.fromlist([sen, labels], self.fields))
    dataset = torchtext.data.Dataset(examples, self.fields)
    
    iterator = torchtext.data.Iterator(dataset,device=self.device,batch_size=64,repeat=False,train=False,sort=False)
        
    # Apply the trained model to all batches.
    out = []
    self.model.eval()
    with torch.no_grad():
      for batch in iterator:
        # Call the model's predict method. This returns a list of NumPy matrix
        # containing the integer-encoded tags for each sentence.
        predicted = self.model.predict(batch.text)

        # Convert the integer-encoded tags to tag strings.
        for tokens, pred_sen in zip(sentences, predicted):
          out.append([self.LABEL.vocab.itos[pred_id] for _, pred_id in zip(tokens, pred_sen[1:])])
    return out
          
  def train(self):
    # Read training and validation data according to the predefined split.
    train_examples = read_data('eng.train', self.fields)
    valid_examples = read_data('eng.train', self.fields)
    
    # Count the number of words and sentences.
    n_tokens_train = 0
    n_sentences_train = 0
    for ex in train_examples:
      n_tokens_train += len(ex.text) + 2
      n_sentences_train += 1
    # print(n_tokens_train)
    n_tokens_valid = 0       
    for ex in valid_examples:
      n_tokens_valid += len(ex.text)

    # Load the pre-trained embeddings that come with the torchtext library.
    use_pretrained = True
    if use_pretrained:
      print('We are using pre-trained word embeddings.')
      self.TEXT.build_vocab(train_examples, vectors="glove.840B.300d")
    else:  
      print('We are training word embeddings from scratch.')
      self.TEXT.build_vocab(train_examples, max_size=5000)
    self.LABEL.build_vocab(train_examples)

    # Create one of the models defined above.

    # self.model = RNNTagger(self.TEXT, self.LABEL, emb_dim=300, rnn_size=128, update_pretrained=False)
    self.model = RNNCRFTagger(self.TEXT, self.LABEL, emb_dim=300, rnn_size=128, update_pretrained=False)

    self.model.to(self.device)

    batch_size = 1024
    n_batches = np.ceil(n_sentences_train / batch_size)

    mean_n_tokens = n_tokens_train / n_batches
    print(train_examples)
    train_iterator = torchtext.data.BucketIterator(train_examples,device=self.device,batch_size=batch_size,sort_key=lambda x: len(x.text),repeat=False,train=True,sort=True)

    valid_iterator = torchtext.data.BucketIterator(valid_examples,device=self.device,batch_size=64,sort_key=lambda x: len(x.text),repeat=False,train=False,sort=True)

    train_batches = list(train_iterator)
    valid_batches = list(valid_iterator)

    optimizer = torch.optim.Adam(self.model.parameters(), lr=0.01, weight_decay=1e-5)

    n_labels = len(self.LABEL.vocab)

    history = defaultdict(list)    
    
    n_epochs = 25
    
    for i in range(1, n_epochs + 1):

      t0 = time.time()

      loss_sum = 0

      self.model.train()
      for batch in train_batches:
          
        # Compute the output and loss.
        loss = self.model(batch.text, batch.label) / mean_n_tokens
        
        optimizer.zero_grad()            
        loss.backward()
        optimizer.step()
        loss_sum += loss.item()

      train_loss = loss_sum / n_batches
      history['train_loss'].append(train_loss)

      # Evaluate on the validation set.
      if i % 1 == 0:
        stats = defaultdict(Counter)

        self.model.eval()
        with torch.no_grad():
          for batch in valid_batches:
            # Predict the model's output on a batch.
            predicted = self.model.predict(batch.text)                   
            # Update the evaluation statistics.
            evaluate_iob(predicted, batch.label, self.LABEL, stats)
    
        # Compute the overall F-score for the validation set.
        _, _, val_f1 = prf(stats['total'])
        
        history['val_f1'].append(val_f1)
    
        t1 = time.time()
        print(f'Epoch {i}: train loss = {train_loss:.4f}, val f1: {val_f1:.4f}, time = {t1-t0:.4f}')
        
    # After the final evaluation, we print more detailed evaluation statistics, including
    # precision, recall, and F-scores for the different types of named entities.
    print()
    print('Final evaluation on the validation set:')
    p, r, f1 = prf(stats['total'])
    print(f'Overall: P = {p:.4f}, R = {r:.4f}, F1 = {f1:.4f}')
    for label in stats:
      if label != 'total':
        p, r, f1 = prf(stats[label])
        print(f'{label:4s}: P = {p:.4f}, R = {r:.4f}, F1 = {f1:.4f}')
    
    plt.plot(history['train_loss'])
    plt.plot(history['val_f1'])
    plt.legend(['training loss', 'validation F-score'])

tagger = Tagger(lower=False)
tagger.train()
# Out:
# Streaming output truncated to the last 5000 lines.
# A O
#
# COMPLETE O
#
# BITCH B
#
# FOREVER O
#
# AND O
#
# IF O
#
# YOU O
#
# ARE O
#
# ALL O
#
# WOMEN O
#
# ARE O
#
# BITCHES B
#
#
#
# "Love O
#
# seeing O
#
# how O
#
# girls O
#
# publicly O
#
# compliment O
#
# each O
#
# other O
#
# ""Oh O
#
# wow. O
#
# Stunnerz. O
#
# Bae""And O
#
# in O
#
# the O
#
# same O
#
# breath O
#
# send O
#
# private O
#
# texts O
#
# to O
#
# their O
#
# friends O
#
# saying O
#
# the O
#
# same O
#
# person O
#
# is O
#
# an O
#
# ""insta-whore O
#
# / O
#
# attention B
#
# whore I
#
# / O
#
# D-craving O
#
# attention B
#
# seeking O
#
# skank B
#
# with I
#
# dumb I
#
# shoes""Hilarious#MoreThanTwoFaces" O
#
#
#
# Why O
#
# would O
#
# u O
#
# play O
#
# with O
#
# my O
#
# pure O
#
# heart O
#
# u O
#
# fucking B
#
# hoe I
#
# bitch? O
#
#
#
# ugly O
#
# skank B
#
# bitch I
#
# >:( O
#
#
#
# THEN O
#
# STOP O
#
# SAYING O
#
# IT O
#
# CHRISTINA O
#
# , O
#
# fucking B
#
# pussy I
#
# stfu I
#
# stop O
#
# jocking O
#
# her O
#
# she O
#
# dont O
#
# be O
#
# worried O
#
# bout O
#
# you O
#
# you O
#
# acting O
#
# like O
#
# flight O
#
#
#
# honestly O
#
# a O
#
# bitch B
#
# didnt O
#
# deserve O
#
# shit O
#
# this O
#
# whole O
#
# year O
#
# or O
#
# whole O
#
# fuckin B
#
# life O
#
# so O
#
# why O
#
# q O
#
# bitch B
#
# always O
#
# complaining O
#
# ugh O
#
# fucking B
#
# hoe I
#
#
#
# You'd O
#
# be O
#
# the O
#
# one O
#
# to O
#
# know O
#
# about O
#
# hysterical O
#
# woman, O
#
# though O
#
# you O
#
# have O
#
# cornered O
#
# the O
#
# deceptive O
#
# category. O
#
#
#
# "Bitch O
#
# be O
#
# starting O
#
# lmao O
#
# sis O
#
# ""do O
#
# what O
#
# you O
#
# preach""??? O
#
# Speak O
#
# for O
#
# your O
#
# fucking B
#
# self O
#
# you O
#
# fucking B
#
# cunt" O
#
#
#
# .@FLOTUS, O
#
# I O
#
# didn't O
#
# hear O
#
# you O
#
# saying O
#
# anything O
#
# when O
#
# you O
#
# husband O
#
# was O
#
# talking O
#
# about O
#
# grabbing O
#
# women O
#
# by O
#
# the O
#
# pussy. O
#
# That's O
#
# ok O
#
# tho? O
#
# Go O
#
# play O
#
# in O
#
# the O
#
# garden O
#
# in O
#
# your O
#
# stilettos O
#
# and O
#
# stfu! B
#
#
#
# Now O
#
# people O
#
# want O
#
# to O
#
# attack O
#
# eminem O
#
# because O
#
# hes O
#
# older O
#
# and O
#
# they O
#
# think O
#
# hes O
#
# garbage. O
#
# People O
#
# have O
#
# the O
#
# balls O
#
# to O
#
# talk O
#
# shit O
#
# now O
#
# because O
#
# they O
#
# think O
#
# revival O
#
# is O
#
# weak O
#
# and O
#
# whack O
#
# but O
#
# BOYY! O
#
# Why O
#
# didnt O
#
# you O
#
# pussy B
#
# fucks I
#
# respond O
#
# back O
#
# then? O
#
# Scared O
#
# to O
#
# get O
#
# bodied? O
#
#
#
# I O
#
# could O
#
# not O
#
# care O
#
# less O
#
# what O
#
# the O
#
# porn B
#
# model I
#
# skank I
#
# thinks. O
#
#
#
# Hey, O
#
# immigrant B
#
# skank I
#
# ass O
#
# HO, O
#
# look, O
#
# there's O
#
# an O
#
# older, O
#
# fatter O
#
# less O
#
# hair O
#
# dude, O
#
# AND O
#
# HE O
#
# HAS O
#
# 5X O
#
# THE O
#
# THAT O
#
# YOUR O
#
# PATHETIC O
#
# IMMATURE O
#
# HUBBIE O
#
# HAS O
#
# !!! O
#
# GO O
#
# ON, O
#
# GIT B
#
# !! O
#
#
#
# - O
#
# right O
#
# on O
#
# the O
#
# money O
#
# as O
#
# always! O
#
# #MAGAAnn O
#
# Coulter: O
#
# Booker O
#
# and O
#
# Harris O
#
# 'competing O
#
# for O
#
# Most O
#
# Hysterical O
#
# Woman' O
#
#
#
# No O
#
# they O
#
# don't O
#
# get O
#
# it. O
#
# We're O
#
# a O
#
# bunch O
#
# of O
#
# "hysterical O
#
# women" O
#
# as O
#
# they O
#
# put O
#
# it. O
#
#
#
# First O
#
# ima O
#
# smack B
#
# that I
#
# ass I
#
# then O
#
# eat O
#
# that I
#
# pussy B
#
# from O
#
# the O
#
# back O
#
# then O
#
# wrap O
#
# your O
#
# hair O
#
# around O
#
# my O
#
# hand O
#
# while O
#
# I O
#
# choke B
#
# you I
#
# and O
#
# slide O
#
# in O
#
# slow O
#
# and O
#
# long O
#
# strokes O
#
# tease O
#
# u O
#
# then O
#
# start O
#
# pounding O
#
# that I
#
# pussy B
#
#
#
# Stfu B
#
# you O
#
# taking O
#
# all O
#
# this O
#
# shit O
#
# and O
#
# I O
#
# still O
#
# make O
#
# more O
#
# money O
#
# than O
#
# you O
#
# do O
#
# you O
#
# broken O
#
# depression O
#
# pussy B
#
# ass I
#
# bitch I
#
#
#
# Stupid B
#
# dumb B
#
# bitch I
#
# I O
#
# hate B
#
# stupid I
#
# dumb B
#
# bitches I
#
# Like I
#
# stfu I
#
# You I
#
# dumb B
#
# ass I
#
# hoe I
#
# Im O
#
# so O
#
# angry O
#
# That O
#
# youre O
#
# dumb B
#
# and I
#
# stupid I
#
# You I
#
# make O
#
# no O
#
# sense O
#
# Look O
#
# at O
#
# you O
#
# talk O
#
# out O
#
# of O
#
# your O
#
# mouth O
#
# Lmaoo O
#
# BITCH B
#
# you O
#
# mad O
#
# ignorant O
#
# Be O
#
# quiet O
#
# bc O
#
# you O
#
# embarass O
#
# yourself O
#
# Sorry O
#
# youre O
#
# right O
#
# i O
#
# am O
#
# less O
#
# intelligent O
#
#
#
# I O
#
# hate B
#
# bitches I
#
# that O
#
# are O
#
# always O
#
# mad O
#
# at O
#
# the O
#
# world O
#
# for O
#
# no O
#
# reason O
#
# like O
#
# bitch B
#
# stfu I
#
# and O
#
# be O
#
# happy B
#
# hoe I
#
#
#
# What O
#
# a O
#
# liar O
#
# - O
#
# get O
#
# the O
#
# story O
#
# I O
#
# paid O
#
# him O
#
# $380k O
#
# after O
#
# the O
#
# fact O
#
# because O
#
# he O
#
# attacked O
#
# me. O
#
# What O
#
# a O
#
# skank B
#
# and O
#
# so O
#
# is O
#
# every O
#
# woman O
#
# who O
#
# looks O
#
# the O
#
# other O
#
# way O
#
# on O
#
# this O
#
# story O
#
# because O
#
# of O
#
# the O
#
# greater O
#
# good. O
#
#
#
# STUPID B
#
# FUCKING B
#
# CUNT I
#
# ASS I
#
# CUNT I
#
# BITCH I
#
# DIDNT O
#
# STOP O
#
# AT O
#
# HER O
#
# STOP O
#
# SIGN O
#
# AND O
#
# TOTALED O
#
# MY O
#
# FUCKING B
#
# CAR O
#
# THAT O
#
# I O
#
# USE O
#
# TO O
#
# MAKE O
#
# FUCKING B
#
# MONEY O
#
# OH O
#
# MY O
#
# FUCKING B
#
# GOD O
#
# YOU O
#
# STUPID B
#
# FUCKING B
#
# BITCH I
#
#
#
# Oh, O
#
# calm O
#
# down O
#
# you O
#
# hysterical O
#
# woman. O
#
#
#
# Thats O
#
# a O
#
# real O
#
# low O
#
# blow O
#
# to O
#
# hysterical O
#
# women. O
#
#
#
# im O
#
# single O
#
# & O
#
# its O
#
# staying O
#
# that O
#
# way O
#
# for O
#
# a O
#
# long O
#
# time O
#
# because O
#
# I O
#
# hate O
#
# all O
#
# you O
#
# pussy B
#
# niggas! I
#
#
#
# BITCH B
#
# you O
#
# shouldnt O
#
# be O
#
# putting O
#
# it O
#
# out O
#
# there O
#
# cunt B
#
# nugget I
#
#
#
# I O
#
# dont O
#
# have O
#
# Ovaries O
#
# or O
#
# a O
#
# Vagina O
#
# and O
#
# I O
#
# refuse O
#
# to O
#
# put O
#
# women O
#
# in O
#
# jeopardy O
#
# because O
#
# they O
#
# do... O
#
# Pro-choice O
#
# isnt O
#
# pro O
#
# -abortion, O
#
# its O
#
# womens O
#
# right O
#
# to O
#
# choose... O
#
# if O
#
# you O
#
# cant O
#
# get O
#
# pregnant O
#
# from O
#
# rape,STFU. O
#
#
#
# LMAOO O
#
# you O
#
# pussy. O
#
# What O
#
# those O
#
# emojis O
#
# mean?! O
#
#
#
# you O
#
# gonna O
#
# shut O
#
# the O
#
# fuck B
#
# up I
#
# pussy? O
#
#
#
# 2 O
#
# hysterical O
#
# women O
#
# in O
#
# the O
#
# US O
#
# Senate O
#
#
#
# Every O
#
# fine O
#
# fucking B
#
# bitch I
#
# i O
#
# see O
#
# is O
#
# my O
#
# ex O
#
# hoe B
#
#
#
# first O
#
# goes O
#
# to O
#
# bitch B
#
# ass I
#
# janelle. O
#
# FUCK B
#
# YOU I
#
# MESSY O
#
# MF O
#
# ASS B
#
# BITCH I
#
# i O
#
# literally O
#
# was O
#
# on O
#
# a O
#
# call O
#
# with O
#
# her O
#
# and O
#
# her O
#
# dumb O
#
# ass I
#
# twisted O
#
# my O
#
# words O
#
# and O
#
# ran O
#
# to O
#
# tattle O
#
# on O
#
# me O
#
# to O
#
# ari. O
#
# like O
#
# it O
#
# legit O
#
# made O
#
# her O
#
# pussy B
#
# wet O
#
# to O
#
# go O
#
# and O
#
# talk O
#
# shit O
#
# abt O
#
# me O
#
# so O
#
# fuck B
#
# u I
#
# ill O
#
# come O
#
# beat B
#
# ur I
#
# ass I
#
# thats O
#
# why O
#
# u I
#
# stole O
#
# a O
#
# listers O
#
#
#
# How O
#
# is O
#
# it O
#
# that O
#
# no O
#
# law O
#
# enforcement O
#
# entity O
#
# finds O
#
# it O
#
# odd O
#
# that O
#
# you O
#
# can O
#
# leave O
#
# the O
#
# WH O
#
# dead O
#
# broke O
#
# and O
#
# then O
#
# buy O
#
# your O
#
# Skank B
#
# daughter O
#
# a O
#
# $10 O
#
# million O
#
# apartment O
#
# and O
#
# pay O
#
# for O
#
# a O
#
# $3 O
#
# million O
#
# wedding. O
#
# Have O
#
# the O
#
# Clintons O
#
# ever O
#
# gone O
#
# back O
#
# to O
#
# Haiti??? O
#
# #maga B
#
# #tcot I
#
#
#
# You O
#
# know O
#
# whats O
#
# insane O
#
# Dana!! O
#
# Is O
#
# how O
#
# the I
#
# NRA O
#
# continues O
#
# to O
#
# get O
#
# away O
#
# with O
#
# fucking B
#
# murdering I
#
# children I
#
# in I
#
# country! I
#
# Why O
#
# dont O
#
# you O
#
# shut B
#
# the I
#
# fuck I
#
# up I
#
# greedy I
#
# skank I
#
# !! I
#
#
#
# Hard O
#
# to O
#
# figure O
#
# which O
#
# was O
#
# the O
#
# more O
#
# hysterical O
#
# woman, O
#
# Cory O
#
# Booker O
#
# or O
#
# Kamala O
#
# Harris O
#
#
#
# Bitch B
#
# stfu I
#
# stop O
#
# acting O
#
# like O
#
# a O
#
# fucking B
#
# cunt I
#
#
#
# bitch B
#
# if O
#
# you O
#
# dont O
#
# shut B
#
# the I
#
# fuck I
#
# up I
#
# and O
#
# stop O
#
# acting O
#
# like O
#
# the I
#
# us O
#
# isnt O
#
# responsible O
#
# for O
#
# the I
#
# repressive O
#
# and O
#
# brutal O
#
# society O
#
# that O
#
# became O
#
# afghanistan O
#
# - O
#
# theres O
#
# pics O
#
# of O
#
# my O
#
# gma O
#
# in O
#
# miniskirts O
#
# in O
#
# the I
#
# 70s O
#
# in O
#
# iran, O
#
# another O
#
# country O
#
# destabilized O
#
# and O
#
# vilified O
#
# to O
#
# drive O
#
# american O
#
# profit O
#
#
#
# Stfu B
#
# you O
#
# lie O
#
# out O
#
# the O
#
# gate O
#
# lol O
#
# tf O
#
# you O
#
# except O
#
# ! O
#
# You O
#
# want O
#
# pussy B
#
# out O
#
# the O
#
# gate O
#
# !! O
#
#
#
# Says O
#
# the O
#
# supporter O
#
# of O
#
# a O
#
# woman..@HillaryClinton O
#
# ....that O
#
# literally O
#
# protected O
#
# & O
#
# threw O
#
# every O
#
# woman O
#
# under O
#
# the O
#
# bus O
#
# that O
#
# accused O
#
# her O
#
# President O
#
# husband O
#
# of O
#
# rape, O
#
# affairs, O
#
# etc. O
#
# Pleeeeeease, O
#
# STFU, O
#
# or O
#
# educate O
#
# yourself. O
#
#
#
# ______________________| O
#
# | O
#
# Shut O
#
# the O
#
# fuck B
#
# Up I
#
# you I
#
# pussy|______________________| O
#
# \ O
#
# / O
#
# (- O
#
# ) O
#
#
#
# Should O
#
# our O
#
# country O
#
# be O
#
# run O
#
# by O
#
# a O
#
# couple O
#
# hysterical O
#
# women. O
#
#
#
# What O
#
# is O
#
# your O
#
# racist B
#
# skank I
#
# of O
#
# a O
#
# wife O
#
# up O
#
# to O
#
# now O
#
# ? O
#
#
#
# Goddamn O
#
# fucking B
#
# bitch I
#
# shut I
#
# your O
#
# fucking B
#
# flap I
#
# cunt! I
#
# Downplaying O
#
# as O
#
# if O
#
# you O
#
# got O
#
# game O
#
# & O
#
# political O
#
# power O
#
# killing O
#
# all O
#
# US O
#
# presidents O
#
# w/ O
#
# my O
#
# civil O
#
# rights O
#
# violators O
#
# bribed O
#
# in-part O
#
# 1st O
#
# family O
#
# children O
#
# to O
#
# run O
#
# w/criminals O
#
# & O
#
# or O
#
# both O
#
# monopolize O
#
# conspirat O
#
#
#
# Such O
#
# a O
#
# skank B
#
# you O
#
# have O
#
# to O
#
# play O
#
# on O
#
# this.Get O
#
# a O
#
# life O
#
# lol O
#
#
#
# HOW O
#
# FUCKING I
#
# DARE O
#
# YOU O
#
# LOOK O
#
# AT O
#
# HER O
#
# WHILE O
#
# CALLING O
#
# HIM O
#
# HIS O
#
# SPIRITUAL O
#
# SON O
#
# YOU O
#
# CUNT B
#
# FUCKING I
#
# BITCH I
#
#
#
# That's O
#
# rich O
#
# coming O
#
# from O
#
# the O
#
# hysterical O
#
# woman O
#
# who O
#
# didn't O
#
# get O
#
# the O
#
# right O
#
# seat O
#
# on O
#
# an O
#
# airplane. O
#
#
#
# I O
#
# bet O
#
# her O
#
# parents O
#
# dont O
#
# claim O
#
# her O
#
# either. O
#
# This O
#
# skank B
#
# blames O
#
# her O
#
# miserable O
#
# existence O
#
# on O
#
# immigrants O
#
# and O
#
# POC O
#
# when O
#
# as O
#
# an O
#
# attractive O
#
# white O
#
# young O
#
# woman, O
#
# she O
#
# has O
#
# the O
#
# privilege O
#
# to O
#
# do O
#
# anything. O
#
# More O
#
# trump B
#
# trash. I
#
#
#
# People O
#
# in O
#
# Eu O
#
# & O
#
# the O
#
# US O
#
# dont O
#
# seem O
#
# 2understand O
#
# that O
#
# the O
#
# Muslim O
#
# refugees O
#
# coming O
#
# from O
#
# the O
#
# Middle O
#
# East O
#
# r O
#
# very O
#
# poor, O
#
# uneducated, O
#
# &have O
#
# no O
#
# respect O
#
# for O
#
# women, O
#
# children O
#
# or O
#
# animals.They O
#
# do O
#
# what O
#
# was O
#
# ok O
#
# in O
#
# their O
#
# country O
#
# ie O
#
# rape O
#
# women, O
#
# childre O
#
#
#
# Yes O
#
# I O
#
# have O
#
# a O
#
# job O
#
# And O
#
# I'm O
#
# pretty O
#
# damn O
#
# sure O
#
# u O
#
# dont O
#
# make O
#
# remotely O
#
# close O
#
# to O
#
# what O
#
# I O
#
# make O
#
# a O
#
# week O
#
# working O
#
# 25 O
#
# hours O
#
# than O
#
# what O
#
# u O
#
# make O
#
# working O
#
# 80 O
#
# hours O
#
# so O
#
# shut B
#
# the I
#
# fuck I
#
# up. O
#
# I O
#
# clearly O
#
# said O
#
# on O
#
# the I
#
# thread O
#
# I O
#
# had O
#
# time O
#
# yesterday....whore O
#
#
#
# No O
#
# room O
#
# for O
#
# full O
#
# explanation O
#
# here O
#
# but O
#
# regarding O
#
# the O
#
# hysterical O
#
# women O
#
# at O
#
# the O
#
# Kavanaugh O
#
# hearing, O
#
# the O
#
# word O
#
# hysteria O
#
# is O
#
# from O
#
# a O
#
# Greek O
#
# word O
#
# meaning O
#
# wandering O
#
# and O
#
# disconnected O
#
# uterus. O
#
# There O
#
# you O
#
# have O
#
# it. O
#
#
#
# Youre O
#
# not O
#
# going O
#
# to O
#
# die O
#
# so O
#
# shut B
#
# the I
#
# fuck I
#
# up I
#
# moaning O
#
# and O
#
# get O
#
# in O
#
# with O
#
# it O
#
#
#
# did O
#
# you O
#
# fight O
#
# for O
#
# women? O
#
# Ever???? O
#
# Did O
#
# you O
#
# fight O
#
# against O
#
# the O
#
# AESO O
#
# in O
#
# our O
#
# recession? O
#
# Did O
#
# you O
#
# acknowledge O
#
# sustainability O
#
# in O
#
# the O
#
# context O
#
# of O
#
# our O
#
# energy O
#
# industry? O
#
# Ever??? O
#
# Shut O
#
# your O
#
# stupid B
#
# fucking I
#
# cunt I
#
# mouth. O
#
#
#
# fuck B
#
# you I
#
# pussy I
#
# suckin I
#
# bitch. O
#
#
#
# , O
#
# you O
#
# don't O
#
# have O
#
# to O
#
# be O
#
# a O
#
# skank B
#
# anymore. O
#
# He, O
#
# the O
#
# skunk, O
#
# done O
#
# you O
#
# wrong. O
#
# Someone O
#
# standing O
#
# up O
#
# and O
#
# exposing O
#
# your O
#
# philandering O
#
# immoral O
#
# husband O
#
# is O
#
# a O
#
# hero O
#
#
#
# stfu B
#
# bitch I
#
# nigga I
#
# who O
#
# told O
#
# u O
#
# to O
#
# talk O
#
# hoe B
#
#
#
# The O
#
# Queen O
#
# of O
#
# Hysterical O
#
# Women O
#
# tweets O
#
# bitterly, O
#
# terrified O
#
# of O
#
# losing O
#
# her O
#
# crown. O
#
#
#
# Because O
#
# nobody O
#
# wants O
#
# to O
#
# watch O
#
# a O
#
# nasty B
#
# skank I
#
# bitch I
#
# run O
#
# her O
#
# mouth! O
#
#
#
# Hating O
#
# men O
#
# is O
#
# an O
#
# important O
#
# part O
#
# of O
#
# feminism O
#
# why O
#
# cant O
#
# these O
#
# men O
#
# serving O
#
# brats B
#
# just O
#
# shut O
#
# the O
#
# fuck B
#
# up I
#
#
#
# Those O
#
# pics O
#
# look O
#
# like O
#
# theyre O
#
# from O
#
# someone O
#
# mocking O
#
# the O
#
# kind O
#
# of O
#
# people O
#
# who O
#
# would O
#
# disrupt O
#
# hearings. O
#
# Like O
#
# if O
#
# SNL O
#
# was O
#
# fair O
#
# and O
#
# made O
#
# fun O
#
# of O
#
# these O
#
# people, O
#
# the O
#
# exaggerated O
#
# version O
#
# of O
#
# a O
#
# hysterical O
#
# woman O
#
# disrupting O
#
#
#
# Youre O
#
# asking O
#
# about O
#
# the O
#
# Most O
#
# Hysterical O
#
# Woman?Between O
#
# you O
#
# and O
#
# Donald O
#
# Trump, O
#
# I O
#
# now O
#
# definitively O
#
# know O
#
# the O
#
# definition O
#
# of O
#
# Projection. O
#
#
#
# Your O
#
# skank B
#
# ass I
#
# disgusts O
#
# me O
#
# so O
#
# much O
#
#
#
# Stfu B
#
# bitch I
#
# you O
#
# sound O
#
# like O
#
# a O
#
# whole O
#
# ass B
#
# pussy I
#
# bro O
#
# no O
#
# one O
#
# cares O
#
#
#
# Bitch B
#
# stfu I
#
# you O
#
# was O
#
# just O
#
# talking O
#
# shit O
#
# about O
#
# her O
#
# stop O
#
# tryna O
#
# get O
#
# clout O
#
# fat B
#
# neck I
#
# hoe I
#
#
#
# Bitch B
#
# stfu? O
#
# I O
#
# didnt O
#
# asked O
#
# you O
#
# something, O
#
# dumbass B
#
# hoe? O
#
# And O
#
# obsessed? O
#
# Shut O
#
# you O
#
# dirty B
#
# ass, O
#
# cause O
#
# we O
#
# all O
#
# know O
#
# esme O
#
# was O
#
# so O
#
# obsessed O
#
# with O
#
# me O
#
# that O
#
# she O
#
# keeped O
#
# subtweeting O
#
# about O
#
# me O
#
# LOOOOOOOOL O
#
#
#
# Michelle O
#
# Obama O
#
# is O
#
# a O
#
# woman O
#
# that O
#
# every O
#
# woman O
#
# should O
#
# aspire O
#
# to O
#
# be O
#
# where O
#
# Flotus O
#
# is O
#
# a O
#
# skank O
#
# that O
#
# no O
#
# one O
#
# wants O
#
# to O
#
# be O
#
#
#
# Ann, O
#
# I O
#
# thought O
#
# Most O
#
# Hysterical O
#
# Woman O
#
# was O
#
# engraved O
#
# on O
#
# the O
#
# participation O
#
# trophy O
#
# they O
#
# gave O
#
# you O
#
# at O
#
# the O
#
# GOP O
#
# convention. O
#
# Bless O
#
# your O
#
# heart. O
#
#
#
# You O
#
# are O
#
# a O
#
# pussy... O
#
# stand O
#
# up O
#
# or O
#
# shut O
#
# up... O
#
# put O
#
# youre O
#
# head O
#
# above O
#
# the O
#
# parapet O
#
# & O
#
# make O
#
# a O
#
# stance O
#
# or O
#
# keep O
#
# taking O
#
# the O
#
# MP O
#
# wage O
#
# & O
#
# STFU B
#
# x O
#
#
#
# This O
#
# just O
#
# in. O
#
# Many O
#
# are O
#
# saying O
#
# Trump O
#
# now O
#
# at O
#
# 155% O
#
# in O
#
# the O
#
# polls. O
#
# Yuge O
#
# deal, O
#
# that O
#
# I O
#
# can O
#
# tell O
#
# you! O
#
# Witch O
#
# hunt O
#
# over. O
#
# Trump O
#
# innocent. O
#
# Crooked O
#
# Hillary O
#
# voted O
#
# ugliest O
#
# skank B
#
# of O
#
# the O
#
# Decade! O
#
# Bigly! O
#
# Trump O
#
# steaks O
#
# melt O
#
# in O
#
# your O
#
# mouth O
#
# like O
#
# I O
#
# did O
#
# Stormy O
#
# I O
#
# m O
#
#
#
# Wow, O
#
# Stupid O
#
# is O
#
# as O
#
# Stupidity O
#
# does O
#
# These O
#
# stupid B
#
# women I
#
# are O
#
# stupid B
#
# Yet, O
#
# if O
#
# they O
#
# are O
#
# doing O
#
# this O
#
# for O
#
# Trump O
#
# I O
#
# hope O
#
# he O
#
# is O
#
# paying O
#
# them O
#
# $15,000 O
#
# per O
#
# month O
#
# to O
#
# talk,rape O
#
# and O
#
# act O
#
# a O
#
# fool O
#
# for O
#
# him O
#
# IdIots, O
#
# Yea O
#
# you O
#
# two O
#
#
#
# To O
#
# the O
#
# guys O
#
# that O
#
# loved O
#
# me,made O
#
# a O
#
# relationship O
#
# with, O
#
# cheated O
#
# on I
#
# me, O
#
# made O
#
# false O
#
# promises. O
#
# Go O
#
# fuck B
#
# yourself I
#
# and O
#
# I O
#
# hope O
#
# the O
#
# next O
#
# girl O
#
# you O
#
# end O
#
# up O
#
# with O
#
# is O
#
# a O
#
# ugly B
#
# ass I
#
# mother I
#
# fucking B
#
# cunt I
#
# whore I
#
# who I
#
# dicks I
#
# around I
#
# and O
#
# goes O
#
# fucking B
#
# psycho I
#
# on I
#
# your I
#
# ass I
#
# because O
#
# karma O
#
# is O
#
# a O
#
# bitch. O
#
# :) O
#
#
#
# YOU O
#
# ALWAYS O
#
# HAVE O
#
# MY O
#
# DICK. O
#
# ONCE O
#
# YOU O
#
# START O
#
# USING O
#
# MINE O
#
# AND O
#
# YOU O
#
# WILL I
#
# NEVER O
#
# FEEL O
#
# YOU O
#
# PUSSY B
#
# IS O
#
# EMPTY O
#
# AND O
#
# ONCE O
#
# YOUR O
#
# PUSSY B
#
# STARTS O
#
# TASTING O
#
# MY O
#
# DICK B
#
# IT I
#
# WILL I
#
# NOT I
#
# ACCEPT I
#
# OTHER I
#
# DICK, O
#
# IT I
#
# WILL I
#
# DIE O
#
# TO O
#
# HAVE O
#
# MINE O
#
# ALL O
#
# THE O
#
# TIME. O
#
# FUCK B
#
# U I
#
# BABY O
#
#
#
# MUMMY... O
#
# NO O
#
# bitch B
#
# youll O
#
# call O
#
# me O
#
# DADDY O
#
# as O
#
# you I
#
# choke B
#
# on I
#
# my I
#
# big I
#
# dick! O
#
# Youll O
#
# call O
#
# me O
#
# DADDY O
#
# when O
#
# I O
#
# bend O
#
# you I
#
# over O
#
# and O
#
# strech B
#
# that I
#
# cunt I
#
# wide I
#
# & I
#
# split I
#
# you I
#
# in I
#
# two! O
#
# DADDY O
#
# knows O
#
# best. O
#
#
#
# Stfu B
#
# nigga I
#
# you I
#
# a I
#
# fake I
#
# stealing I
#
# peoples O
#
# name O
#
# for O
#
# clout O
#
# how O
#
# do O
#
# you I
#
# feel O
#
# goofy O
#
# bitch... O
#
# Go O
#
# ahead O
#
# and O
#
# block O
#
# me O
#
# pussy B
#
# you I
#
# will O
#
# have O
#
# more O
#
# comments O
#
# coming O
#
#
#
# BITCH B
#
# STFU I
#
# IAN O
#
# CONNOR O
#
# AINT O
#
# A O
#
# FUCKING B
#
# ARTIST. O
#
# The O
#
# life O
#
# of O
#
# one, O
#
# but O
#
# he O
#
# aint O
#
# a O
#
# artist. O
#
# Know O
#
# shit O
#
# before O
#
# you O
#
# speak O
#
#
#
# damm O
#
# baby O
#
# girl O
#
# you O
#
# got O
#
# a O
#
# nice O
#
# pussy B
#
# right O
#
# there O
#
# and O
#
# be O
#
# sites O
#
# you O
#
# pussy B
#
# look O
#
# morh O
#
# bigger O
#
# than O
#
# my O
#
# girl O
#
# pussy B
#
#
#
# Hysterical O
#
# woman O
#
# does O
#
# in O
#
# both O
#
# cases. O
#
# I O
#
# don't O
#
# think O
#
# Booker O
#
# would O
#
# mind O
#
# given O
#
# his O
#
# proclivity O
#
# for O
#
# deliberate O
#
# histrionics. O
#
#
#
# bitch B
#
# stfu I
#
# yall O
#
# call O
#
# angela O
#
# an O
#
# ice O
#
# queen O
#
# but O
#
# then O
#
# say O
#
# oh O
#
# sure O
#
# angelas O
#
# the O
#
# mean O
#
# one O
#
# you O
#
# can O
#
# say O
#
# this O
#
# shit O
#
# and O
#
# still O
#
# recognize O
#
# angela O
#
# being O
#
# a O
#
# whole O
#
# bitch B
#
#
#
# Perhaps O
#
# Ann O
#
# meant O
#
# to O
#
# tweat O
#
# that O
#
# she O
#
# wished O
#
# she O
#
# herself O
#
# had O
#
# been O
#
# present O
#
# to O
#
# compete O
#
# for O
#
# the O
#
# most O
#
# hysterical O
#
# woman? O
#
# Regarding O
#
# Kavanaugh, O
#
# as O
#
# Harris O
#
# & O
#
# Booker's O
#
# questions O
#
# revealed, O
#
# I O
#
# felt O
#
# that O
#
# he O
#
# was O
#
# less O
#
# than O
#
# decisive, O
#
# forthright O
#
# with O
#
# his O
#
# answe O
#
#
#
# Wtf B
#
# is O
#
# that O
#
# skank B
#
# bitch I
#
# Kate O
#
# here?! O
#
# I O
#
# don't O
#
# want O
#
# her O
#
# on O
#
# my O
#
# tv. O
#
#
#
# Why O
#
# Would O
#
# You O
#
# Do O
#
# This O
#
# To O
#
# My O
#
# Young O
#
# Fairly O
#
# Innocent O
#
# Heart O
#
# You O
#
# Fucking B
#
# Hoe I
#
# Bitch. O
#
#
#
# my O
#
# bitch B
#
# cunt I
#
# supervisor O
#
# can O
#
# never O
#
# keep O
#
# my O
#
# name O
#
# outta O
#
# her O
#
# mouth O
#
#
#
# Its O
#
# a O
#
# bitch B
#
# who O
#
# better O
#
# get O
#
# her O
#
# some O
#
# business O
#
# forreal! O
#
# How O
#
# the O
#
# fuck B
#
# u I
#
# gone O
#
# feel O
#
# entitled O
#
# to O
#
# somebody! O
#
# Bitch B
#
# u I
#
# got O
#
# blackballed O
#
# & O
#
# u I
#
# gone O
#
# stay O
#
# blackballed! O
#
# I O
#
# ain't O
#
# saving O
#
# no O
#
# hoe! B
#
# U O
#
# is O
#
# not O
#
# apart O
#
# of O
#
# my O
#
# Spurs O
#
# dreams! O
#
# The O
#
# woman O
#
# u I
#
# see O
#
# on O
#
# my O
#
# page O
#
# had O
#
# on O
#
# the O
#
# San O
#
# Antonio O
#
# Spurs O
#
# Warm O
#
# up O
#
# Jacket O
#
#
#
# Sounds O
#
# like O
#
# & O
#
# are O
#
# still O
#
# competing O
#
# for O
#
# most O
#
# hysterical O
#
# woman O
#
# at O
#
# the O
#
# hearings. O
#
# #Pathetic B
#
# #WeThePeople I
#
# dont O
#
# pay O
#
# you O
#
# to O
#
# clutch O
#
# pearls, O
#
# or O
#
# perform O
#
# one O
#
# act O
#
# plays. O
#
# Get B
#
# your I
#
# sh!t I
#
# together. I
#
# #ConfirmJudgeKavanaugh O
#
# #ConfirmKavanaughNOW#WalkAway O
#
#
#
# Im O
#
# so O
#
# sick B
#
# of I
#
# this I
#
# hoe I
#
# speaking O
#
# on O
#
# me O
#
# bitch B
#
# you O
#
# dont O
#
# know O
#
# SHIT B
#
# STFU I
#
#
#
# Ann:Including O
#
# Sen. O
#
# Cory O
#
# Booker O
#
# as O
#
# part O
#
# of O
#
# your O
#
# "Most O
#
# Hysterical O
#
# Woman"?? O
#
# Come O
#
# on O
#
# now, O
#
# you O
#
# cn O
#
# do O
#
# better O
#
# than O
#
# that. O
#
# This O
#
# is O
#
# so O
#
# beneath O
#
# your O
#
# intellectual O
#
# acumen O
#
# and O
#
# although O
#
# I O
#
# disagree O
#
# with O
#
# most O
#
# of O
#
# what O
#
# you O
#
# say, O
#
# come O
#
# up O
#
# with O
#
# something O
#
# more O
#
# origin O
#
#
#
# Hysterical O
#
# Woman, O
#
# you O
#
# don't O
#
# speak O
#
# for O
#
# me O
#
# or O
#
# other O
#
# women O
#
# in O
#
# my O
#
# household. O
#
#
#
# Lmfao B
#
# shut I
#
# the I
#
# fuck I
#
# up I
#
# with O
#
# your O
#
# Brentwood O
#
# Academy O
#
# havin O
#
# ass. O
#
# Yall O
#
# have O
#
# one O
#
# of O
#
# the I
#
# worst O
#
# QBs O
#
# in O
#
# the I
#
# league O
#
# as O
#
# far O
#
# as O
#
# TD/INT O
#
# ratio O
#
# go O
#
# but O
#
# you O
#
# hate O
#
# on O
#
# every O
#
# other O
#
# quarterback.... O
#
# Sit O
#
# your O
#
# pussy B
#
# ass I
#
# down O
#
# and O
#
# get O
#
# swept O
#
# by O
#
# the I
#
# Titans O
#
# again. O
#
#
#
# Let's O
#
# find O
#
# this O
#
# entitled O
#
# little B
#
# skank I
#
# and O
#
# make O
#
# her O
#
# life O
#
# hell O
#
# for O
#
# as O
#
# long O
#
# as O
#
# it O
#
# takes O
#
# to O
#
# teach O
#
# her O
#
# a O
#
# lesson. O
#
# Portland, O
#
# Oregon, O
#
# someone O
#
# knows O
#
# her. O
#
#
#
# Has O
#
# it O
#
# been O
#
# a O
#
# year O
#
# already? O
#
# Are O
#
# you O
#
# looking O
#
# forward O
#
# to O
#
# giving O
#
# up O
#
# your O
#
# most O
#
# hysterical O
#
# woman( O
#
# tweeting O
#
# about O
#
# seat O
#
# swap O
#
# on O
#
# a O
#
# flight) O
#
# title? O
#
#
#
# Oh O
#
# please O
#
# stfu. O
#
# No O
#
# one O
#
# cares O
#
# Susan O
#
# you O
#
# told O
#
# everyone O
#
# Hillary O
#
# was O
#
# worse O
#
# than O
#
# trump O
#
# you O
#
# no O
#
# longer O
#
# get O
#
# to O
#
# tell O
#
# us O
#
# anything O
#
#
#
# PSAYoure O
#
# a O
#
# slut B
#
# but O
#
# you O
#
# dont O
#
# fuck B
#
# meBecause O
#
# you O
#
# sound O
#
# like O
#
# a O
#
# cry O
#
# baby O
#
# bitch B
#
# shut I
#
# the I
#
# fuck B
#
# up I
#
# already I
#
#
#
# To O
#
# take O
#
# over O
#
# your O
#
# reign O
#
# of O
#
# the O
#
# Most O
#
# Hysterical O
#
# Woman O
#
# on O
#
# a O
#
# Delta O
#
# Airlines O
#
# flight? O
#
#
#
# Ann, O
#
# ever O
#
# think O
#
# you O
#
# might O
#
# be O
#
# a O
#
# bit O
#
# hysterical O
#
# yourself. O
#
# You O
#
# lost O
#
# your O
#
# ability O
#
# to O
#
# reason O
#
# long O
#
# ago. O
#
# Not O
#
# sure O
#
# when O
#
# you O
#
# had O
#
# the O
#
# heartectomy. O
#
# One O
#
# thing O
#
# for O
#
# sure. O
#
# You O
#
# don't O
#
# belong O
#
# in O
#
# the O
#
# human O
#
# race. O
#
# Damn. O
#
#
#
# Some O
#
# gold-digging B
#
# skank I
#
# has O
#
# stupid O
#
# opinions. O
#
#
#
# Unless O
#
# cow O
#
# tipping O
#
# is O
#
# classed O
#
# as O
#
# physical O
#
# assault O
#
# you I
#
# should O
#
# shut O
#
# your O
#
# fucking B
#
# whore I
#
# mouth, O
#
# i O
#
# hope O
#
# you I
#
# never O
#
# show O
#
# your O
#
# face O
#
# outside O
#
# of O
#
# whatever O
#
# hole O
#
# you I
#
# went O
#
# to O
#
# hide O
#
# in O
#
# because O
#
# frankly O
#
# i O
#
# would O
#
# love O
#
# to O
#
# drop B
#
# kick I
#
# you I
#
# off I
#
# a I
#
# fucking B
#
# balcony I
#
# xoxoxo O
#
#
#
# You B
#
# fucking I
#
# cunt! I
#
# You B
#
# dont O
#
# take O
#
# reporting O
#
# seriously! O
#
# You B
#
# fucking I
#
# and I
#
# disgusting I
#
# bitch! I
#
# You B
#
# are I
#
# a I
#
# disgrace I
#
# for I
#
# women. I
#
# Youre I
#
# a I
#
# monster! I
#
#
#
# Simply O
#
# put O
#
#
#
# I O
#
# fucking B
#
# hate I
#
# this I
#
# bitch I
#
# Naga I
#
# on O
#
# #bbcbreakfast O
#
# Stop O
#
# interrupting O
#
# people O
#
# you O
#
# ignorant O
#
# cunt.You're O
#
# not O
#
# the O
#
# expert. O
#
# STFU B
#
#
#
# Get O
#
# a O
#
# hobby O
#
# you O
#
# pussy. O
#
# #TrumpTrain2020 O
#
#
#
# stfu B
#
# bitch I
#
#
#
# Are O
#
# your O
#
# children O
#
# safe O
#
# living O
#
# with O
#
# a O
#
# skank B
#
# like O
#
# you? O
#
# I O
#
# certainly O
#
# hope O
#
# not. O
#
#
#
# I O
#
# would O
#
# enjoy O
#
# standing O
#
# back O
#
# to O
#
# watch O
#
# you O
#
# suck B
#
# cocks I
#
# and O
#
# swallow O
#
# huge O
#
# loads O
#
# of O
#
# cum, O
#
# while O
#
# you're O
#
# helpless. O
#
# As O
#
# you O
#
# suck B
#
# each O
#
# cock O
#
# I'll O
#
# finger O
#
# your O
#
# pussy O
#
# until O
#
# you O
#
# cum, O
#
# while O
#
# you O
#
# choke O
#
# on O
#
# cocks I
#
# and O
#
# cum! O
#
# When O
#
# I O
#
# do O
#
# take O
#
# you O
#
# home, O
#
# you'll O
#
# be O
#
# exhauste O
#
#
#
# fucking B
#
# cunt I
#
# whore I
#
# slut I
#
# pussy I
#
# bitch I
#
# fuck I
#
# you O
#
#
#
# We are using pre-trained word embeddings.
# .vector_cache/glove.840B.300d.zip:  12%|█▏        | 252M/2.18G [01:34<1:29:58, 357kB/s]

# %%
def print_tags(sentence):
  tokens = sentence.split()
  tags = tagger.tag([tokens])[0]
  for token, tag in zip(tokens, tags):
    print(f'{token:12s}{tag}')

# %%
print_tags("@DevilGrimz: @VigxRArts you're fucking gay, blacklisted hoe Holding out for #TehGodClan anyway http://t.co/xUCcwoetmn	")

# %%
print_tags("@TheoMaxximus: #GerrysHalloweenParty http://t.co/3ycrSrnjHc Halloween was yesterday stupid nigger")

# %%
print_tags("Don't worry about the nigga you see, worry about the nigga you DON'T see... Dat's da nigga fuckin yo bitch.")

# %%
print_tags("ayo i even kill handicapped and crippled bitches/look at my scalp real close and you'll see triple sixes")

# %%
print_tags("on my way to fuck your bitch in the name of The Lord - Mr. Race")

# %%
print_tags("#AZmonsoon lot of rain, too bad it wasn't enough to wash away the teabagger racist white trash in the state. #Tcot #teaparty #azflooding")

# %%
print_tags("#Dutch farmers are white trash.")

# %%
print_tags("#JesusChrist was STRAIGHT&gt; That's why the #faggots killed him. #PERIOD #SonOfGod&gt;")
